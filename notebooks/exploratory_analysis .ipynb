# %%
import pandas as pd

# %% [markdown]
# ## Data exploration
# First glance at the data and an example of review.
# Some of the text in the column "review" needs a bit of processing.

# %%
df_train = pd.read_csv("../../data/train.csv")
df_test = pd.read_csv("../../data/test.csv")
df_valid = pd.read_csv("../../data/valid.csv")

df_train.head()
# Out:
#    Unnamed: 0                                           film-url  \
# 0           0  http://www.allocine.fr/film/fichefilm-135259/c...
# 1           1  http://www.allocine.fr/film/fichefilm-172430/c...
# 2           2  http://www.allocine.fr/film/fichefilm-15105/cr...
# 3           3  http://www.allocine.fr/film/fichefilm-188629/c...
# 4           4  http://www.allocine.fr/film/fichefilm-23514/cr...
#
#                                               review  polarity
# 0  Si vous cherchez du cinéma abrutissant à tous ...         0
# 1  Trash, re-trash et re-re-trash...! Une horreur...         0
# 2  Et si, dans les 5 premières minutes du film, l...         0
# 3  Mon dieu ! Quelle métaphore filée ! Je suis ab...         0
# 4  Premier film de la saga Kozure Okami, "Le Sabr...         1

# %%
df_train["review"][0]
# Out:
# 'Si vous cherchez du cinéma abrutissant à tous les étages,n\'ayant aucune peur du cliché en castagnettes et moralement douteux,"From Paris with love" est fait pour vous.Toutes les productions Besson,via sa filière EuropaCorp ont de quoi faire naître la moquerie.Paris y est encore une fois montrée comme une capitale exotique,mais attention si l\'on se dirige vers la banlieue,on y trouve tout plein d\'intégristes musulmans prêts à faire sauter le caisson d\'une ambassadrice américaine.Nauséeux.Alors on se dit qu\'on va au moins pouvoir apprécier la déconnade d\'un classique buddy-movie avec le jeune agent aux dents longues obligé de faire équipe avec un vieux lou complètement timbré.Mais d\'un côté,on a un Jonathan Rhys-meyers fayot au possible,et de l\'autre un John Travolta en total délire narcissico-badass,crâne rasé et bouc proéminent à l\'appui.Sinon,il n\'y a aucun scénario.Seulement,des poursuites débiles sur l\'autoroute,Travolta qui étale 10 mecs à l\'arme blanche en 8 mouveme
# ...

# %% [markdown]
# ### Check for missing value
# There is not a single missing value

# %%
print(df_train.isnull().values.any())
print(df_train.isnull().values.any())
print(df_train.isnull().values.any())
# Out:
# False
# False
# False

# %% [markdown]
# ### Label distribution

# %%
print("Number of review assigned with polarity 0 =>",df_train["polarity"][df_train["polarity"] == 0].count())
print("Number of review assigned with polarity 1 =>",df_train["polarity"][df_train["polarity"] == 1].count())
# Out:
# Number of review assigned with polarity 0 => 79413
# Number of review assigned with polarity 1 => 80587
